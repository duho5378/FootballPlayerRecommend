# %%
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.preprocessing import OneHotEncoder

import numpy as np
import pandas as pd

# %%
import warnings

# Tắt tất cả các cảnh báo
warnings.filterwarnings("ignore")

# %%
# encoder = OneHotEncoder(sparse=False)

# # One-hot encoding cho cả hai cột 'work_rate' và 'body_type'
# one_hot_encoded = encoder.fit_transform(df_st[['work_rate', 'body_type']])
# # one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['work_rate', 'body_type']))

# # Ghép kết quả vào DataFrame gốc
# df_st = pd.concat([df_st, one_hot_df], axis=1)

# # Xóa các cột gốc đã được one-hot encoding
# df_st = df_st.drop(['work_rate', 'body_type'], axis=1)

# # In kết quả
# df_st.head(10)

# %% [markdown]
# - Đọc dữ liệu.
# - Chia data.
# - Chọn data.
# - Convert phép tính.
# - Học máy.

# %%
from sklearn import linear_model
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics

positions = ['st', 'lw', 'lf', 'cf', 'rf', 'rw', 'cam', 'lm', 
            'cm', 'rm','lwb', 'cdm', 'rwb', 'lb', 'cb', 'rb']

for i in positions:
    df = pd.read_csv(f'./data/player_stat_fl_pos/{i}_player.csv')
    label = df[f'{i}']
    data = df.iloc[:, 2:43]
#     print(data)
#     print(label)
    
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.2, random_state=42)
    model = linear_model.LinearRegression(fit_intercept=False)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)
    sse = np.sum((y_test - y_pred) ** 2)

    mse = metrics.mean_squared_error(y_test, y_pred)

    print(f'MSE {i}: {mse}')

# print(df_st.shape)
# print(st_labels.shape)

# X_train, X_test, y_train, y_test = train_test_split(df_st, st_labels, test_size=0.2, random_state=42)
# print(len(y_test))



# model = linear_model.LinearRegression(fit_intercept=False)

# model.fit(X_train, y_train)

# y_pred = model.predict(X_test)
# sse = np.sum((y_test - y_pred) ** 2)

# mse = metrics.mean_squared_error(y_test, y_pred)

# print(f'MSE: {mse}')
# Out:
# MSE st: 0.4410853735148951
# MSE lw: 0.11038880482783738
# MSE lf: 0.11038880482783768
# MSE cf: 0.09564278359574424
# MSE rf: 0.10287252379798241
# MSE rw: 0.1028725237979821
# MSE cam: 0.6150599076829796
# MSE lm: 0.400917741845072
# MSE cm: 0.5118147888606313
# MSE rm: 0.4664868529767106
# MSE lwb: 0.18204535378916972
# MSE cdm: 0.5297673821274403
# MSE rwb: 0.17618310977899213
# MSE lb: 0.12698651414279655
# MSE cb: 0.4814279740217088
# MSE rb: 0.17198928737306368

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Tắt tất cả các cảnh báo
warnings.filterwarnings("ignore")
data = pd.DataFrame()
for i in positions:
    df = pd.read_csv(f'./data/player_stat_fl_pos/{i}_player.csv')
    temp = df[f'{i}']
    sns.kdeplot(data=temp, shade=False)
plt.title('Biểu đồ mật độ của điểm của các vị trí')

# Hiển thị biểu đồ
plt.show()

# %%
cosine_similarity_matrix = pd.read_csv('./data/cosine_player/cam_similarity.csv')

# sns.boxplot(data=cosine_similarity_matrix)
plt.boxplot(cosine_similarity_matrix.iloc[0])

# Đặt tiêu đề cho biểu đồ
plt.title('Biểu đồ Boxplot của Ma trận độ đo cosine')

# Hiển thị biểu đồ
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dữ liệu mẫu
np.random.seed(10)
data = np.random.normal(0, 1, 100)
print(data)

# Vẽ biểu đồ boxplot
plt.boxplot(data)

# Đặt tiêu đề cho biểu đồ
plt.title('Biểu đồ Boxplot')

# Hiển thị biểu đồ
plt.show()
# Out:
# [ 1.3315865   0.71527897 -1.54540029 -0.00838385  0.62133597 -0.72008556
#   0.26551159  0.10854853  0.00429143 -0.17460021  0.43302619  1.20303737
#  -0.96506567  1.02827408  0.22863013  0.44513761 -1.13660221  0.13513688
#   1.484537   -1.07980489 -1.97772828 -1.7433723   0.26607016  2.38496733
#   1.12369125  1.67262221  0.09914922  1.39799638 -0.27124799  0.61320418
#  -0.26731719 -0.54930901  0.1327083  -0.47614201  1.30847308  0.19501328
#   0.40020999 -0.33763234  1.25647226 -0.7319695   0.66023155 -0.35087189
#  -0.93943336 -0.48933722 -0.80459114 -0.21269764 -0.33914025  0.31216994
#   0.56515267 -0.14742026 -0.02590534  0.2890942  -0.53987907  0.70816002
#   0.84222474  0.2035808   2.39470366  0.91745894 -0.11227247 -0.36218045
#  -0.23218226 -0.5017289   1.12878515 -0.69781003 -0.08112218 -0.52929608
#   1.04618286 -1.41855603 -0.36249918 -0.12190569  0.31935642  0.4609029
#  -0.21578989  0.98907246  0.31475378  2.46765106 -1.50832149  0.62060066
# ...

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# Tạo một DataFrame mẫu đại diện cho ma trận độ đo cosine
# Giả sử cosine_similarity_matrix là ma trận của bạn
# Đây là một DataFrame mẫu:
cosine_similarity_matrix = pd.DataFrame(np.random.rand(10, 10), columns=['Player1', 'Player2', 'Player3', 'Player4', 'Player5', 'Player6', 'Player7', 'Player8', 'Player9', 'Player10'])

# Vẽ biểu đồ boxplot của ma trận độ đo cosine
sns.boxplot(data=cosine_similarity_matrix)

# Đặt tiêu đề cho biểu đồ
plt.title('Biểu đồ Boxplot của Ma trận độ đo cosine')

# Hiển thị biểu đồ
plt.show()
